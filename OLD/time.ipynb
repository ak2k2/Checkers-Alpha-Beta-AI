# %%
from timeit import timeit
from game import simulate_random_game_to_time

def time_random_game():
    simulate_random_game_to_time()
    

print(timeit(time_random_game, number=5000))
# Out:
# 8.963660443027038

# %%
from game_np import simulate_random_game_np

def time_random_game_np():
    simulate_random_game_np()

print(timeit(time_random_game_np, number=1000))
# Out:
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,1
# X's turn with move 1,0->2,1
# O's turn with move 5,6->4,7
# X's turn with move 2,5->3,4
# O's turn with move 4,7->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,4->3,6
# X's turn with move 3,2->4,3
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 0,1->1,0
# O's turn with move 6,3->5,2
# X's turn with move 1,6->2,7
# O's turn with move 7,4->6,3
# X's turn with move 2,7->4,5
# O's turn with move 6,3->5,4
# X's turn with move 4,5->6,3
# O's turn with move 7,2->5,4
# X's turn with move 0,7->1,6
# O's turn with move 3,2->2,3
# X's turn with move 1,4->3,2
# O's turn with move 6,7->5,6
# X's turn with move 1,2->2,3
# O's turn with move 7,6->6,7
# X's turn with move 0,3->1,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,5->4,7
# X's turn with move 4,3->6,5
# O's turn with move 6,7->5,6
# X's turn with move 6,5->7,6
# O's turn with move 5,6->4,5
# X's turn with move 1,6->2,7
# O's turn with move 6,1->5,0
# X's turn with move 0,5->1,6
# O's turn with move 4,5->3,6
# X's turn with move 2,7->4,5
# O's turn with move 7,0->6,1
# X's turn with move 1,4->2,5
# O's turn with move 5,2->4,3
# X's turn with move 3,2->5,4
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 5,0->4,1
# X's turn with move 1,6->2,5
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# X's turn with move 2,7->3,6
# O's turn with move 5,6->4,5
# X's turn with move 2,1->3,0
# O's turn with move 4,5->2,7
# X's turn with move 1,0->2,1
# O's turn with move 5,0->4,1
# X's turn with move 2,5->3,4
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,4->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 4,1->5,0
# O's turn with move 4,5->3,6
# X's turn with move 2,1->3,2
# O's turn with move 6,5->5,4
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 1,4->2,5
# O's turn with move 3,6->1,4
# X's turn with move 0,3->2,5
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,1->4,3
# X's turn with move 1,2->2,1
# O's turn with move 3,2->1,0
# X's turn with move 5,0->6,1
# O's turn with move 7,0->5,2
# X's turn with move 0,5->1,4
# O's turn with move 2,7->0,5
# X's turn with move 0,7->1,6
# O's turn with move 7,4->6,5
# X's turn with move 1,6->2,7
# O's turn with move 6,5->5,4
# X's turn with move 2,5->3,6
# O's turn with move 7,6->6,7
# X's turn with move 1,4->2,3
# O's turn with move 4,3->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,2->4,1
# X's turn with move 4,5->5,6
# O's turn with move 6,7->4,5
# X's turn with move 3,6->4,7
# O's turn with move 6,3->5,2
# X's turn with move 4,7->5,6
# O's turn with move 4,1->3,2
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 0,1->1,2
# O's turn with move 7,2->6,3
# X's turn with move 1,2->2,3
# O's turn with move 3,2->1,4
# X's turn with move 5,6->6,5
# O's turn with move 5,4->4,3
# X's turn with move 6,5->7,4
# O's turn with move 6,3->5,4
# X's turn with move 2,1->3,2
# O's turn with move 5,6->4,7
# X's turn with move 1,0->2,1
# O's turn with move 4,7->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,5->4,7
# O's turn with move 5,2->4,1
# X's turn with move 1,6->2,7
# O's turn with move 6,3->5,2
# X's turn with move 2,3->3,4
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 5,2->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,5->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,1->4,3
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,3
# X's turn with move 0,5->1,4
# O's turn with move 6,7->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,4->5,6
# X's turn with move 1,2->2,3
# O's turn with move 5,0->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,3->4,1
# X's turn with move 2,3->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,4->3,6
# O's turn with move 5,6->4,7
# X's turn with move 3,6->4,5
# O's turn with move 4,1->3,0
# X's turn with move 0,3->1,4
# O's turn with move 7,6->6,5
# X's turn with move 4,5->5,4
# O's turn with move 6,5->4,3
# X's turn with move 0,7->1,6
# O's turn with move 7,0->6,1
# X's turn with move 1,4->2,5
# O's turn with move 4,3->3,4
# X's turn with move 2,5->4,3
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# O's turn with move 3,0->2,1
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 2,1->1,0
# X's turn with move 3,4->4,3
# X's turn with move 2,7->3,6
# O's turn with move 5,6->4,5
# X's turn with move 2,3->3,2
# O's turn with move 4,5->2,7
# X's turn with move 1,2->2,3
# O's turn with move 5,4->4,5
# X's turn with move 0,3->1,2
# O's turn with move 6,5->5,4
# X's turn with move 2,5->3,4
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,1->4,3
# X's turn with move 1,6->2,5
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 4,3->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,7->5,6
# X's turn with move 1,4->2,5
# O's turn with move 6,3->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,6->5,4
# X's turn with move 0,5->1,4
# O's turn with move 5,6->4,7
# X's turn with move 1,0->2,1
# O's turn with move 7,4->6,3
# X's turn with move 0,1->1,0
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 2,7->1,6
# X's turn with move 0,7->2,5
# O's turn with move 5,4->4,3
# X's turn with move 2,1->3,0
# O's turn with move 6,3->5,4
# X's turn with move 2,5->3,6
# O's turn with move 4,5->2,7
# X's turn with move 1,0->2,1
# O's turn with move 7,2->6,1
# X's turn with move 5,0->7,2
# O's turn with move 4,3->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,3->4,1
# O's turn with move 7,0->6,1
# X's turn with move 1,2->2,3
# O's turn with move 6,1->5,0
# X's turn with move 1,4->2,5
# O's turn with move 5,0->3,2
# X's turn with move 2,3->4,1
# O's turn with move 2,7->1,6
# X's turn with move 4,1->5,2
# O's turn with move 1,6->0,7
# X's turn with move 4,7->5,6
# X's turn with move 2,5->3,6
# O's turn with move 5,6->4,5
# X's turn with move 2,1->3,0
# O's turn with move 5,0->4,1
# X's turn with move 1,2->2,1
# O's turn with move 6,7->5,6
# X's turn with move 3,6->4,7
# O's turn with move 4,5->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,6->3,4
# X's turn with move 4,7->5,6
# O's turn with move 6,5->4,7
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,4->3,6
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 0,1->1,2
# O's turn with move 3,4->2,3
# X's turn with move 1,2->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,6->2,5
# O's turn with move 7,2->6,3
# X's turn with move 2,1->3,2
# O's turn with move 6,3->5,4
# X's turn with move 3,2->5,0
# O's turn with move 7,6->6,5
# X's turn with move 5,0->7,2
# O's turn with move 5,2->4,3
# X's turn with move 0,3->1,2
# O's turn with move 2,3->0,1
# X's turn with move 3,0->4,1
# O's turn with move 4,3->3,2
# X's turn with move 2,5->3,4
# O's turn with move 7,4->6,3
# X's turn with move 3,4->4,3
# O's turn with move 5,4->4,5
# X's turn with move 1,0->2,1
# O's turn with move 3,2->1,0
# X's turn with move 4,3->5,2
# O's turn with move 4,5->3,4
# X's turn with move 5,2->7,4
# O's turn with move 6,5->5,6
# X's turn with move 0,5->1,6
# O's turn with move 5,6->4,5
# X's turn with move 1,6->2,5
# O's turn with move 3,4->1,6
# X's turn with move 0,7->2,5
# O's turn with move 4,5->3,4
# X's turn with move 2,5->4,3
# O's turn with move 7,0->6,1
# X's turn with move 4,1->5,0
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,3
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,3->4,1
# O's turn with move 6,3->5,2
# X's turn with move 4,1->6,3
# O's turn with move 7,4->5,2
# X's turn with move 1,4->2,3
# O's turn with move 7,2->6,3
# X's turn with move 1,2->2,1
# O's turn with move 5,6->4,5
# X's turn with move 0,5->1,4
# O's turn with move 4,3->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,7->3,6
# O's turn with move 3,4->1,2
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 0,3->2,1
# O's turn with move 6,3->5,4
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 7,6->6,5
# X's turn with move 1,4->2,3
# O's turn with move 5,4->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,5->4,3
# X's turn with move 0,1->1,0
# O's turn with move 4,3->3,2
# X's turn with move 2,3->4,1
# O's turn with move 6,1->5,0
# X's turn with move 1,6->2,7
# O's turn with move 5,0->3,2
# X's turn with move 0,7->1,6
# O's turn with move 7,0->6,1
# X's turn with move 1,0->2,1
# O's turn with move 3,2->1,0
# X's turn with move 1,6->2,5
# O's turn with move 6,1->5,2
# X's turn with move 2,5->3,4
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 1,0->0,1
# X's turn with move 5,2->6,3
# O's turn with move 6,7->5,6
# X's turn with move 6,3->7,4
# O's turn with move 5,6->4,5
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 2,3->3,2
# O's turn with move 5,6->4,7
# X's turn with move 2,5->3,4
# O's turn with move 5,4->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 3,2->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,4->2,5
# O's turn with move 6,3->5,4
# X's turn with move 2,5->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,2->3,4
# O's turn with move 3,0->1,2
# X's turn with move 0,1->2,3
# O's turn with move 6,5->5,6
# X's turn with move 3,4->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 1,6->2,5
# O's turn with move 7,2->6,3
# X's turn with move 2,5->3,4
# O's turn with move 3,2->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,1->5,2
# X's turn with move 0,3->1,4
# O's turn with move 6,3->5,4
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 1,4->2,5
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 7,0->6,1
# X's turn with move 4,7->6,5
# O's turn with move 7,4->5,6
# X's turn with move 0,7->1,6
# O's turn with move 5,6->4,7
# X's turn with move 3,4->4,5
# O's turn with move 7,6->6,5
# X's turn with move 4,5->5,4
# O's turn with move 6,5->4,3
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 4,3->2,5
# X's turn with move 0,5->1,6
# O's turn with move 2,5->0,7
# X's turn with move 2,5->3,6
# O's turn with move 5,4->4,3
# X's turn with move 2,3->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,0->4,1
# X's turn with move 1,4->2,5
# O's turn with move 4,1->3,0
# X's turn with move 2,1->3,2
# O's turn with move 3,0->2,1
# X's turn with move 1,2->3,0
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,3->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 0,5->1,6
# O's turn with move 7,0->6,1
# X's turn with move 0,1->1,2
# O's turn with move 5,6->4,7
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 4,3->2,5
# X's turn with move 2,7->3,6
# O's turn with move 6,1->5,0
# X's turn with move 3,0->4,1
# O's turn with move 5,0->3,2
# X's turn with move 3,6->4,7
# O's turn with move 2,5->1,6
# X's turn with move 0,7->2,5
# O's turn with move 3,2->2,1
# X's turn with move 1,0->3,2
# O's turn with move 7,6->6,5
# X's turn with move 4,7->5,6
# O's turn with move 6,5->4,7
# X's turn with move 3,2->4,1
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 7,2->6,1
# X's turn with move 4,1->5,0
# O's turn with move 7,4->6,5
# X's turn with move 5,0->7,2
# O's turn with move 6,7->5,6
# X's turn with move 1,2->2,1
# O's turn with move 5,6->4,5
# X's turn with move 2,1->3,0
# O's turn with move 4,5->3,4
# X's turn with move 3,0->4,1
# O's turn with move 3,4->2,3
# X's turn with move 4,1->5,0
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 2,3->1,4
# X's turn with move 0,3->2,5
# X's turn with move 2,7->3,6
# O's turn with move 5,0->4,1
# X's turn with move 1,6->2,7
# O's turn with move 5,2->4,3
# X's turn with move 2,5->3,4
# O's turn with move 4,3->2,5
# X's turn with move 2,3->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 5,6->4,5
# X's turn with move 1,2->2,3
# O's turn with move 4,5->3,4
# X's turn with move 2,3->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 6,1->5,0
# X's turn with move 0,7->1,6
# O's turn with move 2,5->0,7
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,3->5,4
# X's turn with move 3,6->4,7
# O's turn with move 5,4->3,2
# X's turn with move 0,5->1,6
# O's turn with move 3,2->2,3
# X's turn with move 0,1->1,2
# O's turn with move 2,3->0,1
# X's turn with move 1,0->2,1
# O's turn with move 7,4->6,3
# X's turn with move 1,6->2,5
# O's turn with move 7,0->6,1
# X's turn with move 0,3->1,2
# O's turn with move 5,0->4,1
# X's turn with move 2,1->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 6,3->5,2
# X's turn with move 2,7->3,6
# O's turn with move 7,2->6,3
# X's turn with move 3,4->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,6->5,4
# X's turn with move 4,3->6,5
# O's turn with move 6,3->5,4
# X's turn with move 6,5->7,4
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,1->5,2
# X's turn with move 6,7->7,6
# O's turn with move 5,2->4,3
# X's turn with move 5,4->6,5
# O's turn with move 4,3->3,2
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,1
# X's turn with move 2,5->3,6
# O's turn with move 6,1->5,2
# X's turn with move 1,0->2,1
# O's turn with move 7,2->6,1
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,6->3,4
# X's turn with move 1,4->2,5
# O's turn with move 4,1->3,0
# X's turn with move 2,5->4,3
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 1,2->2,1
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 6,5->5,6
# X's turn with move 0,1->1,0
# O's turn with move 5,6->4,7
# X's turn with move 3,6->4,5
# O's turn with move 7,6->6,5
# X's turn with move 4,5->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,1->3,0
# O's turn with move 6,7->5,6
# X's turn with move 1,6->2,5
# O's turn with move 4,5->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 1,0->2,1
# O's turn with move 4,7->3,6
# X's turn with move 0,5->1,4
# O's turn with move 3,6->2,5
# X's turn with move 1,4->3,6
# O's turn with move 6,5->5,6
# X's turn with move 3,6->4,5
# O's turn with move 3,4->2,3
# X's turn with move 4,5->6,7
# O's turn with move 7,4->6,5
# X's turn with move 6,7->7,6
# O's turn with move 2,3->1,2
# X's turn with move 3,0->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 1,2->0,3
# X's turn with move 0,7->1,6
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# X's turn with move 2,3->3,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 1,2->2,3
# O's turn with move 5,4->4,3
# X's turn with move 2,5->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,2->4,1
# X's turn with move 3,4->5,6
# O's turn with move 6,5->4,7
# X's turn with move 2,3->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 7,6->6,5
# X's turn with move 0,7->1,6
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 6,3->5,4
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,3
# X's turn with move 5,0->7,2
# O's turn with move 6,3->5,2
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,4->4,3
# X's turn with move 0,5->1,4
# O's turn with move 4,3->2,5
# X's turn with move 1,4->3,6
# O's turn with move 7,0->6,1
# X's turn with move 0,3->1,4
# O's turn with move 7,4->6,3
# X's turn with move 3,6->4,5
# O's turn with move 5,2->4,3
# X's turn with move 4,5->5,6
# O's turn with move 6,5->4,7
# X's turn with move 3,0->4,1
# O's turn with move 4,7->3,6
# X's turn with move 4,1->5,2
# O's turn with move 6,3->4,1
# X's turn with move 1,4->2,3
# O's turn with move 6,1->5,0
# X's turn with move 0,1->1,2
# O's turn with move 3,6->2,5
# X's turn with move 1,0->2,1
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 1,2->2,3
# O's turn with move 3,2->1,0
# X's turn with move 2,3->3,4
# O's turn with move 2,5->1,4
# X's turn with move 3,4->5,2
# O's turn with move 1,4->0,3
# X's turn with move 5,2->6,3
# O's turn with move 1,0->0,1
# X's turn with move 6,3->7,4
# X's turn with move 2,3->3,4
# O's turn with move 5,4->4,5
# X's turn with move 1,2->2,3
# O's turn with move 5,6->4,7
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 2,1->3,2
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 6,5->5,4
# X's turn with move 4,7->5,6
# O's turn with move 7,4->6,5
# X's turn with move 5,6->7,4
# O's turn with move 5,2->4,1
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 0,1->1,2
# O's turn with move 7,6->6,7
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 1,2->2,1
# O's turn with move 6,3->5,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,3->4,5
# O's turn with move 4,1->3,0
# X's turn with move 1,4->2,3
# O's turn with move 6,1->5,2
# X's turn with move 1,0->2,1
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 7,0->6,1
# X's turn with move 1,6->2,5
# O's turn with move 5,2->4,3
# X's turn with move 0,5->1,6
# O's turn with move 2,7->0,5
# X's turn with move 2,3->3,4
# O's turn with move 6,1->5,2
# X's turn with move 2,5->3,6
# O's turn with move 4,3->2,5
# X's turn with move 2,1->3,2
# O's turn with move 2,5->1,6
# X's turn with move 0,7->2,5
# O's turn with move 7,2->6,1
# X's turn with move 3,6->4,7
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 6,7->5,6
# X's turn with move 5,0->7,2
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 4,7->5,6
# O's turn with move 3,4->2,3
# X's turn with move 5,6->6,5
# O's turn with move 2,3->1,4
# X's turn with move 6,5->7,6
# O's turn with move 1,4->0,3
# X's turn with move 2,1->3,2
# O's turn with move 5,6->4,7
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,2->2,3
# O's turn with move 6,5->5,6
# X's turn with move 1,0->2,1
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 7,4->6,5
# X's turn with move 2,7->3,6
# O's turn with move 6,1->5,2
# X's turn with move 2,3->3,4
# O's turn with move 7,2->6,1
# X's turn with move 3,6->4,5
# O's turn with move 5,4->3,6
# X's turn with move 0,1->1,0
# O's turn with move 6,1->5,0
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 1,4->2,3
# O's turn with move 3,4->1,2
# X's turn with move 2,1->3,2
# O's turn with move 1,2->0,1
# X's turn with move 1,6->2,7
# O's turn with move 6,7->5,6
# X's turn with move 2,7->4,5
# O's turn with move 5,6->3,4
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 0,7->1,6
# O's turn with move 6,5->5,6
# X's turn with move 1,6->2,7
# O's turn with move 7,0->6,1
# X's turn with move 0,5->1,6
# O's turn with move 3,2->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,3->5,4
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 1,6->2,7
# O's turn with move 3,4->2,3
# X's turn with move 2,7->3,6
# O's turn with move 2,5->1,6
# X's turn with move 3,6->4,7
# O's turn with move 6,1->5,0
# X's turn with move 4,7->6,5
# O's turn with move 7,6->5,4
# X's turn with move 2,5->3,6
# O's turn with move 5,2->4,1
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,7->4,5
# O's turn with move 6,1->5,2
# X's turn with move 1,6->2,5
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,0->4,1
# X's turn with move 0,7->1,6
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,4->5,6
# X's turn with move 1,2->2,1
# O's turn with move 6,3->5,2
# X's turn with move 0,3->1,2
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 1,2->2,1
# O's turn with move 7,0->6,1
# X's turn with move 0,1->1,2
# O's turn with move 5,6->4,5
# X's turn with move 2,1->3,2
# O's turn with move 4,5->3,6
# X's turn with move 1,4->2,5
# O's turn with move 3,6->1,4
# X's turn with move 0,5->2,3
# O's turn with move 7,2->6,3
# X's turn with move 2,3->4,5
# O's turn with move 6,3->5,4
# X's turn with move 4,5->6,3
# O's turn with move 7,6->6,5
# X's turn with move 6,3->7,2
# O's turn with move 6,1->5,0
# X's turn with move 1,2->2,1
# O's turn with move 6,5->5,6
# X's turn with move 1,6->2,5
# O's turn with move 5,6->4,7
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# X's turn with move 2,1->3,0
# O's turn with move 5,4->4,5
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 2,3->3,2
# O's turn with move 5,6->4,5
# X's turn with move 3,0->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,2->2,3
# O's turn with move 3,0->2,1
# X's turn with move 0,1->1,2
# O's turn with move 6,7->5,6
# X's turn with move 1,2->3,0
# O's turn with move 4,5->3,4
# X's turn with move 2,5->4,3
# O's turn with move 7,6->6,7
# X's turn with move 4,3->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 0,3->1,2
# O's turn with move 2,3->0,1
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 3,0->4,1
# O's turn with move 5,6->4,7
# X's turn with move 1,0->2,1
# O's turn with move 3,2->1,0
# X's turn with move 1,6->2,5
# O's turn with move 6,5->5,6
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,4->3,6
# O's turn with move 7,4->6,3
# X's turn with move 4,1->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 0,7->1,6
# O's turn with move 6,7->5,6
# X's turn with move 1,6->2,5
# O's turn with move 3,4->1,6
# X's turn with move 0,5->1,4
# O's turn with move 6,3->5,2
# X's turn with move 1,4->2,3
# O's turn with move 7,0->6,1
# X's turn with move 2,3->3,2
# O's turn with move 4,3->2,1
# X's turn with move 2,3->3,4
# O's turn with move 5,4->4,3
# X's turn with move 2,5->3,6
# O's turn with move 4,3->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,3->4,1
# X's turn with move 1,4->2,5
# O's turn with move 6,5->5,4
# X's turn with move 0,5->1,4
# O's turn with move 7,4->6,5
# X's turn with move 1,2->2,3
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 0,1->1,2
# O's turn with move 7,2->6,3
# X's turn with move 2,5->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,4->3,6
# O's turn with move 7,6->6,5
# X's turn with move 2,3->3,4
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,3->5,4
# X's turn with move 0,3->1,4
# O's turn with move 5,4->3,2
# X's turn with move 1,4->2,5
# O's turn with move 3,2->2,3
# X's turn with move 1,2->2,1
# O's turn with move 2,3->1,4
# X's turn with move 0,7->1,6
# O's turn with move 6,5->5,4
# X's turn with move 3,6->4,7
# O's turn with move 5,4->4,3
# X's turn with move 4,7->6,5
# O's turn with move 6,1->5,2
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 1,4->0,5
# X's turn with move 3,4->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 5,2->4,1
# X's turn with move 6,5->7,4
# O's turn with move 4,1->2,3
# X's turn with move 2,7->3,6
# O's turn with move 7,0->6,1
# X's turn with move 3,6->4,7
# O's turn with move 6,1->5,2
# X's turn with move 4,7->5,6
# O's turn with move 5,2->4,3
# X's turn with move 2,5->3,6
# O's turn with move 2,3->1,4
# X's turn with move 1,6->2,7
# O's turn with move 1,4->0,3
# X's turn with move 6,7->7,6
# O's turn with move 4,3->3,4
# X's turn with move 3,6->4,5
# O's turn with move 3,4->2,5
# X's turn with move 5,6->6,5
# O's turn with move 2,5->1,4
# X's turn with move 2,7->3,6
# O's turn with move 5,0->4,1
# X's turn with move 3,6->4,7
# O's turn with move 4,1->3,2
# X's turn with move 4,5->5,4
# O's turn with move 3,2->2,1
# X's turn with move 4,7->5,6
# O's turn with move 2,1->1,0
# X's turn with move 5,6->6,7
# O's turn with move 1,0->0,1
# X's turn with move 5,4->6,3
# X's turn with move 2,3->3,2
# O's turn with move 5,2->4,1
# X's turn with move 1,4->2,3
# O's turn with move 4,1->3,0
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,6->5,4
# X's turn with move 0,5->1,4
# O's turn with move 6,1->5,0
# X's turn with move 2,7->3,6
# O's turn with move 7,2->6,1
# X's turn with move 1,2->2,3
# O's turn with move 6,1->5,2
# X's turn with move 2,3->3,2
# O's turn with move 7,0->6,1
# X's turn with move 1,4->2,3
# O's turn with move 7,4->6,5
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,4->3,6
# X's turn with move 0,1->1,2
# O's turn with move 6,1->5,2
# X's turn with move 1,2->2,1
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 5,2->4,1
# X's turn with move 2,1->3,0
# O's turn with move 4,1->2,3
# X's turn with move 1,6->2,7
# O's turn with move 6,3->5,2
# X's turn with move 2,7->4,5
# O's turn with move 2,3->1,2
# X's turn with move 0,7->1,6
# O's turn with move 6,5->5,6
# X's turn with move 1,0->2,1
# O's turn with move 5,6->3,4
# X's turn with move 1,6->2,5
# O's turn with move 3,4->1,6
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 1,2->0,1
# X's turn with move 3,2->4,3
# O's turn with move 1,6->0,5
# X's turn with move 4,3->5,4
# O's turn with move 6,7->5,6
# X's turn with move 5,4->6,5
# O's turn with move 5,6->4,5
# X's turn with move 5,2->6,3
# O's turn with move 5,0->4,1
# X's turn with move 6,5->7,4
# O's turn with move 4,5->3,6
# X's turn with move 6,3->7,2
# O's turn with move 3,6->2,7
# X's turn with move 2,3->3,4
# O's turn with move 5,4->4,5
# X's turn with move 3,4->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 4,5->3,4
# X's turn with move 2,7->3,6
# O's turn with move 5,6->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 1,4->2,3
# O's turn with move 6,7->5,6
# X's turn with move 1,6->2,5
# O's turn with move 3,4->1,6
# X's turn with move 0,7->2,5
# O's turn with move 7,2->6,3
# X's turn with move 2,3->3,2
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 2,1->3,0
# O's turn with move 6,3->5,4
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 1,2->2,1
# O's turn with move 4,5->3,6
# X's turn with move 2,5->4,7
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 7,4->6,3
# X's turn with move 2,1->4,3
# O's turn with move 6,3->4,1
# X's turn with move 4,3->5,2
# O's turn with move 4,1->3,0
# X's turn with move 0,1->1,2
# O's turn with move 5,6->4,5
# X's turn with move 1,0->2,1
# O's turn with move 5,0->4,1
# X's turn with move 0,5->1,6
# O's turn with move 4,5->3,4
# X's turn with move 5,2->6,1
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 3,4->2,5
# X's turn with move 1,6->3,4
# O's turn with move 7,6->6,7
# X's turn with move 4,3->5,4
# O's turn with move 6,5->4,3
# X's turn with move 3,4->5,2
# O's turn with move 3,0->2,1
# X's turn with move 1,2->3,0
# O's turn with move 6,7->5,6
# X's turn with move 4,7->6,5
# X's turn with move 2,7->3,6
# O's turn with move 5,0->4,1
# X's turn with move 2,5->3,4
# O's turn with move 5,4->4,3
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,3->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 4,3->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 3,6->4,7
# O's turn with move 6,5->5,4
# X's turn with move 1,4->2,5
# O's turn with move 6,1->5,2
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 0,5->1,4
# O's turn with move 5,4->4,3
# X's turn with move 1,4->2,3
# O's turn with move 6,3->5,4
# X's turn with move 2,3->4,5
# O's turn with move 5,4->3,6
# X's turn with move 1,6->2,7
# O's turn with move 3,6->2,5
# X's turn with move 1,0->2,1
# O's turn with move 4,3->3,4
# X's turn with move 2,1->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,2->2,1
# O's turn with move 7,2->6,1
# X's turn with move 0,3->1,2
# O's turn with move 7,6->6,5
# X's turn with move 0,7->1,6
# O's turn with move 2,5->0,7
# X's turn with move 0,1->1,0
# O's turn with move 2,3->0,1
# X's turn with move 2,1->3,2
# O's turn with move 6,1->5,2
# X's turn with move 3,2->4,3
# O's turn with move 7,4->6,3
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 6,7->7,6
# O's turn with move 5,2->4,1
# X's turn with move 4,7->5,6
# O's turn with move 6,5->4,7
# X's turn with move 1,0->2,1
# O's turn with move 6,3->5,4
# X's turn with move 2,1->3,2
# O's turn with move 4,1->2,3
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 2,5->3,6
# O's turn with move 5,2->4,1
# X's turn with move 2,1->3,2
# O's turn with move 6,3->5,2
# X's turn with move 3,6->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,3->4,5
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 5,2->4,1
# X's turn with move 1,6->2,7
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 5,0->4,1
# X's turn with move 1,0->2,1
# O's turn with move 6,1->5,2
# X's turn with move 0,3->1,4
# O's turn with move 6,5->5,6
# X's turn with move 1,4->2,3
# O's turn with move 7,2->6,3
# X's turn with move 0,5->1,4
# O's turn with move 4,1->3,2
# X's turn with move 2,1->4,3
# O's turn with move 7,4->6,5
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 2,3->3,2
# O's turn with move 5,2->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,5->4,3
# X's turn with move 3,4->5,2
# O's turn with move 5,6->3,4
# X's turn with move 5,2->7,4
# O's turn with move 6,7->5,6
# X's turn with move 0,1->1,2
# O's turn with move 7,6->6,5
# X's turn with move 2,7->3,6
# O's turn with move 5,6->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 1,2->2,3
# O's turn with move 3,4->1,2
# X's turn with move 0,7->1,6
# O's turn with move 4,3->3,4
# X's turn with move 1,4->2,5
# O's turn with move 3,4->2,3
# X's turn with move 2,5->3,6
# O's turn with move 1,2->0,1
# X's turn with move 3,6->4,5
# O's turn with move 2,3->1,4
# X's turn with move 4,5->5,6
# O's turn with move 1,4->0,3
# X's turn with move 5,6->6,5
# X's turn with move 2,3->3,2
# O's turn with move 5,2->4,1
# X's turn with move 2,7->3,6
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 6,3->5,2
# X's turn with move 2,1->3,0
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,4->5,2
# O's turn with move 7,0->6,1
# X's turn with move 5,2->7,0
# O's turn with move 7,2->6,1
# X's turn with move 0,1->1,2
# O's turn with move 5,4->4,3
# X's turn with move 3,6->4,7
# O's turn with move 4,3->3,2
# X's turn with move 1,2->2,1
# O's turn with move 6,1->5,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 7,4->6,3
# X's turn with move 1,4->2,5
# O's turn with move 6,3->5,4
# X's turn with move 0,3->1,2
# O's turn with move 5,4->3,2
# X's turn with move 2,5->3,4
# O's turn with move 3,2->2,1
# X's turn with move 1,0->3,2
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 1,6->2,5
# O's turn with move 4,5->3,6
# X's turn with move 1,2->2,1
# O's turn with move 3,6->1,4
# X's turn with move 0,5->2,3
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,6->5,4
# X's turn with move 2,1->3,0
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 5,4->4,3
# X's turn with move 3,0->4,1
# O's turn with move 4,3->3,2
# X's turn with move 2,3->3,4
# O's turn with move 3,2->2,3
# X's turn with move 5,0->6,1
# O's turn with move 2,3->1,4
# X's turn with move 3,4->4,5
# O's turn with move 1,4->0,3
# X's turn with move 0,7->1,6
# X's turn with move 2,3->3,2
# O's turn with move 5,6->4,5
# X's turn with move 3,2->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,6->5,4
# X's turn with move 1,0->2,1
# O's turn with move 5,0->4,1
# X's turn with move 1,6->2,5
# O's turn with move 4,5->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,1->5,0
# X's turn with move 0,1->1,0
# O's turn with move 7,2->6,1
# X's turn with move 2,7->3,6
# O's turn with move 6,3->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,4->5,6
# X's turn with move 0,7->1,6
# O's turn with move 4,1->3,2
# X's turn with move 1,6->2,5
# O's turn with move 5,6->4,7
# X's turn with move 1,0->2,1
# O's turn with move 3,2->1,0
# X's turn with move 1,4->2,3
# O's turn with move 6,1->5,2
# X's turn with move 0,5->1,4
# O's turn with move 1,0->0,1
# X's turn with move 2,5->3,4
# O's turn with move 4,7->2,5
# X's turn with move 1,4->3,6
# O's turn with move 6,7->5,6
# X's turn with move 3,6->4,5
# O's turn with move 7,0->6,1
# X's turn with move 4,5->6,7
# O's turn with move 5,2->4,1
# X's turn with move 0,3->1,4
# O's turn with move 6,1->5,2
# X's turn with move 2,3->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 5,2->4,1
# X's turn with move 3,4->4,3
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 5,0->4,1
# X's turn with move 3,4->4,5
# O's turn with move 4,1->3,0
# X's turn with move 6,7->7,6
# O's turn with move 3,0->2,1
# X's turn with move 4,3->5,4
# O's turn with move 2,1->1,2
# X's turn with move 5,4->6,3
# O's turn with move 1,2->0,3
# X's turn with move 6,3->7,2
# X's turn with move 2,7->3,6
# O's turn with move 5,2->4,3
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,2->3,0
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,5->3,6
# O's turn with move 4,5->2,7
# X's turn with move 1,0->2,1
# O's turn with move 7,4->6,3
# X's turn with move 2,3->3,2
# O's turn with move 6,1->5,2
# X's turn with move 3,0->4,1
# O's turn with move 5,2->3,0
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 3,0->2,1
# X's turn with move 0,1->1,0
# O's turn with move 5,6->4,7
# X's turn with move 1,0->3,2
# O's turn with move 6,3->5,2
# X's turn with move 4,3->6,1
# O's turn with move 7,2->5,0
# X's turn with move 1,4->2,3
# O's turn with move 6,7->5,6
# X's turn with move 0,3->1,4
# O's turn with move 7,0->6,1
# X's turn with move 2,3->3,4
# O's turn with move 4,7->3,6
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 1,4->2,5
# O's turn with move 3,6->1,4
# X's turn with move 0,5->2,3
# O's turn with move 3,4->1,2
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 1,6->2,5
# O's turn with move 3,2->2,1
# X's turn with move 0,7->1,6
# O's turn with move 2,7->0,5
# X's turn with move 2,5->3,6
# O's turn with move 6,5->5,6
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,5->3,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 2,1->3,0
# O's turn with move 5,0->4,1
# X's turn with move 1,4->2,5
# O's turn with move 4,5->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,5->4,7
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,4->5,6
# X's turn with move 1,6->2,7
# O's turn with move 6,3->5,4
# X's turn with move 2,7->3,6
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 7,6->6,7
# X's turn with move 4,1->6,3
# O's turn with move 5,6->4,7
# X's turn with move 1,2->2,1
# O's turn with move 4,7->2,5
# X's turn with move 0,5->1,4
# O's turn with move 5,4->4,5
# X's turn with move 1,4->3,6
# O's turn with move 7,2->5,4
# X's turn with move 0,7->1,6
# O's turn with move 4,5->2,7
# X's turn with move 0,3->1,2
# O's turn with move 2,7->0,5
# X's turn with move 2,1->3,2
# O's turn with move 5,4->4,5
# X's turn with move 3,2->4,1
# O's turn with move 4,5->3,4
# X's turn with move 4,1->5,0
# O's turn with move 6,7->5,6
# X's turn with move 5,0->7,2
# O's turn with move 3,4->2,3
# X's turn with move 1,2->3,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 7,0->6,1
# X's turn with move 5,6->6,5
# O's turn with move 6,1->5,0
# X's turn with move 6,5->7,4
# O's turn with move 5,0->4,1
# X's turn with move 3,0->5,2
# X's turn with move 2,5->3,6
# O's turn with move 5,0->4,1
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,3
# X's turn with move 3,2->5,0
# O's turn with move 4,3->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,4->4,3
# X's turn with move 1,4->2,3
# O's turn with move 5,6->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 1,2->2,1
# O's turn with move 4,5->3,6
# X's turn with move 2,7->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 7,2->6,3
# X's turn with move 5,0->7,2
# O's turn with move 6,5->5,4
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 5,4->4,5
# X's turn with move 4,1->5,0
# O's turn with move 4,5->3,4
# X's turn with move 2,3->4,5
# O's turn with move 7,6->6,5
# X's turn with move 1,6->2,5
# O's turn with move 6,5->5,6
# X's turn with move 0,3->1,4
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 7,0->6,1
# X's turn with move 0,1->1,0
# O's turn with move 6,3->5,2
# X's turn with move 0,5->1,6
# O's turn with move 5,2->3,4
# X's turn with move 6,7->7,6
# O's turn with move 7,4->6,3
# X's turn with move 3,2->4,1
# O's turn with move 6,3->5,4
# X's turn with move 1,4->2,5
# O's turn with move 3,4->2,3
# X's turn with move 1,0->2,1
# O's turn with move 2,3->1,4
# X's turn with move 2,5->3,4
# O's turn with move 1,4->0,5
# X's turn with move 2,1->3,0
# O's turn with move 5,4->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,1->4,3
# X's turn with move 1,6->2,7
# O's turn with move 4,3->3,2
# X's turn with move 2,7->3,6
# O's turn with move 3,2->2,1
# X's turn with move 3,6->4,7
# O's turn with move 2,1->1,2
# X's turn with move 4,7->5,6
# O's turn with move 1,2->0,1
# X's turn with move 4,1->5,2
# X's turn with move 2,3->3,4
# O's turn with move 5,0->4,1
# X's turn with move 3,4->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,1->4,3
# O's turn with move 4,1->3,2
# X's turn with move 1,2->2,1
# O's turn with move 5,6->4,7
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,4->3,6
# O's turn with move 6,3->5,4
# X's turn with move 4,3->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,6->4,7
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,4->5,6
# X's turn with move 0,1->1,2
# O's turn with move 4,3->3,4
# X's turn with move 2,1->4,3
# O's turn with move 5,4->3,2
# X's turn with move 0,5->1,4
# O's turn with move 7,0->6,1
# X's turn with move 1,6->2,7
# O's turn with move 6,1->5,0
# X's turn with move 0,7->1,6
# O's turn with move 5,0->4,1
# X's turn with move 1,0->2,1
# O's turn with move 3,2->1,0
# X's turn with move 2,7->3,6
# O's turn with move 4,1->3,2
# X's turn with move 1,2->2,1
# O's turn with move 5,6->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,7->5,6
# X's turn with move 2,1->4,3
# O's turn with move 3,4->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 7,6->6,7
# X's turn with move 1,4->2,3
# O's turn with move 6,7->4,5
# X's turn with move 2,3->3,2
# O's turn with move 4,5->3,4
# X's turn with move 5,4->6,5
# O's turn with move 1,0->0,1
# X's turn with move 6,5->7,6
# O's turn with move 7,2->6,3
# X's turn with move 4,3->5,4
# O's turn with move 6,3->4,5
# X's turn with move 3,2->4,3
# O's turn with move 3,4->2,3
# X's turn with move 4,3->5,4
# O's turn with move 4,5->3,6
# X's turn with move 0,3->1,2
# O's turn with move 2,3->1,4
# X's turn with move 1,2->2,1
# O's turn with move 3,6->2,7
# X's turn with move 2,1->3,2
# O's turn with move 2,7->1,6
# X's turn with move 5,4->6,3
# O's turn with move 1,4->0,3
# X's turn with move 6,3->7,2
# O's turn with move 1,6->0,5
# X's turn with move 3,2->4,3
# X's turn with move 2,5->3,6
# O's turn with move 5,2->4,3
# X's turn with move 2,3->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,0->4,1
# X's turn with move 3,6->4,7
# O's turn with move 6,1->5,0
# X's turn with move 3,4->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,1
# X's turn with move 3,0->5,2
# O's turn with move 6,3->4,1
# X's turn with move 1,0->2,1
# O's turn with move 6,1->5,2
# X's turn with move 0,5->1,6
# O's turn with move 7,0->6,1
# X's turn with move 4,7->5,6
# O's turn with move 6,7->4,5
# X's turn with move 2,1->3,0
# O's turn with move 6,5->5,6
# X's turn with move 1,2->2,1
# O's turn with move 5,2->4,3
# X's turn with move 3,0->5,2
# O's turn with move 5,6->4,7
# X's turn with move 5,2->7,0
# O's turn with move 7,6->6,5
# X's turn with move 1,4->2,5
# O's turn with move 5,0->4,1
# X's turn with move 0,1->1,2
# O's turn with move 4,5->3,6
# X's turn with move 1,2->2,3
# O's turn with move 3,6->1,4
# X's turn with move 0,3->2,5
# O's turn with move 3,4->1,2
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 4,3->2,5
# X's turn with move 2,1->3,0
# O's turn with move 1,2->0,3
# X's turn with move 3,0->5,2
# O's turn with move 2,5->1,6
# X's turn with move 0,7->2,5
# O's turn with move 7,4->6,3
# X's turn with move 5,2->7,4
# O's turn with move 6,5->5,4
# X's turn with move 2,5->3,4
# O's turn with move 5,4->4,3
# X's turn with move 3,4->5,2
# X's turn with move 2,1->3,0
# O's turn with move 5,0->4,1
# X's turn with move 2,5->3,4
# O's turn with move 5,4->4,3
# X's turn with move 2,3->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 6,5->5,4
# X's turn with move 1,2->2,1
# O's turn with move 7,4->6,5
# X's turn with move 0,5->1,4
# O's turn with move 5,2->4,1
# X's turn with move 3,2->5,0
# O's turn with move 5,4->4,3
# X's turn with move 3,4->5,2
# O's turn with move 6,1->4,3
# X's turn with move 0,1->1,0
# O's turn with move 6,3->5,2
# X's turn with move 5,0->6,1
# O's turn with move 7,2->5,0
# X's turn with move 0,3->1,2
# O's turn with move 6,5->5,4
# X's turn with move 1,4->2,3
# O's turn with move 5,4->4,5
# X's turn with move 1,6->2,5
# O's turn with move 7,6->6,5
# X's turn with move 3,0->4,1
# O's turn with move 5,2->3,0
# X's turn with move 2,5->3,4
# O's turn with move 4,3->2,5
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,2->3,4
# O's turn with move 3,0->1,2
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,7->3,6
# O's turn with move 7,0->6,1
# X's turn with move 1,0->2,1
# O's turn with move 5,0->4,1
# X's turn with move 0,7->1,6
# O's turn with move 2,5->0,7
# X's turn with move 3,6->4,7
# O's turn with move 1,2->0,1
# X's turn with move 2,1->3,0
# O's turn with move 4,1->3,2
# X's turn with move 3,0->4,1
# O's turn with move 3,4->2,3
# X's turn with move 4,1->5,0
# O's turn with move 6,5->5,6
# X's turn with move 4,7->6,5
# O's turn with move 2,3->1,4
# X's turn with move 5,0->7,2
# O's turn with move 1,4->0,5
# X's turn with move 6,5->7,6
# O's turn with move 3,2->2,3
# X's turn with move 2,1->3,0
# O's turn with move 5,4->4,3
# X's turn with move 2,3->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,5->5,4
# X's turn with move 1,2->2,1
# O's turn with move 5,4->4,5
# X's turn with move 3,2->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 6,3->5,2
# X's turn with move 1,4->2,3
# O's turn with move 5,2->3,4
# X's turn with move 3,0->4,1
# O's turn with move 3,4->1,2
# X's turn with move 0,1->2,3
# O's turn with move 7,6->6,5
# X's turn with move 2,3->3,2
# O's turn with move 5,6->4,7
# X's turn with move 3,2->4,3
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,4->5,6
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 4,5->2,3
# X's turn with move 4,1->5,0
# O's turn with move 5,6->4,7
# X's turn with move 0,7->1,6
# O's turn with move 6,1->5,2
# X's turn with move 0,3->1,4
# O's turn with move 2,3->1,2
# X's turn with move 1,4->2,3
# O's turn with move 4,7->3,6
# X's turn with move 2,3->3,4
# O's turn with move 7,2->6,1
# X's turn with move 5,0->7,2
# O's turn with move 5,2->4,1
# X's turn with move 3,4->4,3
# O's turn with move 1,2->0,3
# X's turn with move 1,6->2,5
# O's turn with move 3,6->1,4
# X's turn with move 0,5->2,3
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 6,7->5,6
# X's turn with move 4,3->5,2
# O's turn with move 5,6->4,7
# X's turn with move 5,2->6,1
# O's turn with move 7,0->5,2
# X's turn with move 4,1->6,3
# O's turn with move 4,7->3,6
# X's turn with move 6,3->7,4
# O's turn with move 3,6->2,5
# X's turn with move 2,1->3,2
# O's turn with move 5,4->4,5
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,2->3,4
# O's turn with move 5,6->4,7
# X's turn with move 3,2->4,3
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 6,5->5,4
# X's turn with move 4,3->6,5
# O's turn with move 7,4->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,6->5,4
# X's turn with move 3,4->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,7->4,5
# O's turn with move 5,0->4,1
# X's turn with move 0,1->1,2
# O's turn with move 4,1->3,0
# X's turn with move 1,4->2,3
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 5,2->4,3
# X's turn with move 1,2->2,1
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 6,1->5,0
# X's turn with move 2,3->3,4
# O's turn with move 4,3->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,0->4,1
# X's turn with move 0,5->1,4
# O's turn with move 6,3->5,2
# X's turn with move 3,4->4,5
# O's turn with move 5,2->4,3
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,4->3,2
# O's turn with move 7,0->6,1
# X's turn with move 3,2->4,3
# O's turn with move 6,1->5,0
# X's turn with move 4,3->5,2
# O's turn with move 7,2->6,1
# X's turn with move 5,2->7,0
# O's turn with move 5,0->4,1
# X's turn with move 4,5->5,6
# O's turn with move 4,1->3,2
# X's turn with move 5,6->6,5
# O's turn with move 3,2->2,3
# X's turn with move 6,5->7,4
# O's turn with move 2,3->1,4
# X's turn with move 6,7->7,6
# O's turn with move 1,4->0,5
# X's turn with move 0,7->1,6
# X's turn with move 2,7->3,6
# O's turn with move 5,0->4,1
# X's turn with move 2,1->3,0
# O's turn with move 6,1->5,0
# X's turn with move 1,0->2,1
# O's turn with move 4,1->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,4->3,2
# X's turn with move 3,0->4,1
# O's turn with move 6,5->5,4
# X's turn with move 1,4->2,5
# O's turn with move 6,3->5,2
# X's turn with move 4,1->6,3
# O's turn with move 7,4->5,2
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,5->4,3
# O's turn with move 5,2->3,4
# X's turn with move 1,2->2,3
# O's turn with move 3,2->1,4
# X's turn with move 0,5->2,3
# O's turn with move 3,4->1,2
# X's turn with move 0,1->2,3
# O's turn with move 7,0->6,1
# X's turn with move 0,3->1,4
# O's turn with move 6,1->5,0
# X's turn with move 1,4->2,5
# O's turn with move 5,0->4,1
# X's turn with move 2,3->3,4
# O's turn with move 5,4->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 2,5->3,6
# O's turn with move 4,5->2,7
# ...
# X's turn with move 1,2->2,1
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,4->5,2
# O's turn with move 5,6->4,7
# X's turn with move 3,6->4,5
# O's turn with move 5,4->3,6
# X's turn with move 0,5->1,4
# O's turn with move 3,6->2,7
# X's turn with move 5,2->6,1
# O's turn with move 7,0->5,2
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,3
# X's turn with move 1,4->2,3
# O's turn with move 6,3->5,4
# X's turn with move 2,3->3,4
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 4,7->3,6
# X's turn with move 0,3->1,4
# O's turn with move 5,4->4,3
# X's turn with move 5,0->6,1
# O's turn with move 4,3->3,4
# X's turn with move 0,7->1,6
# O's turn with move 2,7->0,5
# X's turn with move 6,1->7,2
# O's turn with move 3,6->2,5
# X's turn with move 1,4->3,6
# O's turn with move 7,6->6,7
# X's turn with move 1,0->2,1
# O's turn with move 3,4->2,3
# X's turn with move 3,6->4,7
# O's turn with move 2,3->1,2
# X's turn with move 0,1->2,3
# O's turn with move 7,4->6,3
# X's turn with move 5,2->7,4
# O's turn with move 6,5->5,4
# X's turn with move 3,0->4,1
# O's turn with move 6,7->5,6
# X's turn with move 4,7->6,5
# O's turn with move 5,4->4,3
# X's turn with move 2,1->3,0
# O's turn with move 4,3->3,2
# X's turn with move 4,1->5,2
# O's turn with move 3,2->1,4
# X's turn with move 3,0->4,1
# O's turn with move 1,4->0,3
# X's turn with move 5,2->6,1
# X's turn with move 2,5->3,6
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,2->3,0
# O's turn with move 7,4->6,5
# X's turn with move 1,0->2,1
# O's turn with move 6,5->5,4
# X's turn with move 1,6->2,5
# O's turn with move 7,6->6,5
# X's turn with move 0,7->1,6
# O's turn with move 5,6->4,7
# X's turn with move 2,7->3,6
# O's turn with move 5,2->4,3
# X's turn with move 0,3->1,2
# O's turn with move 4,3->3,4
# X's turn with move 2,3->4,5
# O's turn with move 6,3->5,2
# X's turn with move 4,5->6,3
# O's turn with move 7,2->5,4
# X's turn with move 0,1->1,0
# O's turn with move 5,4->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 1,6->2,7
# O's turn with move 4,7->3,6
# X's turn with move 2,7->4,5
# O's turn with move 4,3->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 1,2->2,1
# O's turn with move 5,2->4,3
# X's turn with move 1,4->2,3
# O's turn with move 4,3->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 2,1->4,3
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# X's turn with move 2,5->3,6
# O's turn with move 5,6->4,5
# X's turn with move 2,1->3,0
# O's turn with move 5,4->4,3
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 1,4->2,5
# O's turn with move 4,3->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,0->3,2
# X's turn with move 0,5->1,4
# O's turn with move 3,2->2,3
# X's turn with move 1,4->3,2
# O's turn with move 6,5->5,6
# X's turn with move 3,2->4,1
# O's turn with move 5,6->4,7
# X's turn with move 4,1->6,3
# O's turn with move 7,2->5,4
# X's turn with move 2,5->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,2->3,4
# O's turn with move 6,7->5,6
# X's turn with move 3,4->4,3
# O's turn with move 5,4->3,2
# X's turn with move 0,3->1,2
# O's turn with move 7,6->6,7
# X's turn with move 1,6->2,5
# O's turn with move 5,6->4,5
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 0,7->1,6
# O's turn with move 2,5->0,7
# X's turn with move 1,2->2,3
# O's turn with move 3,2->1,4
# X's turn with move 1,0->2,1
# O's turn with move 7,4->6,3
# X's turn with move 2,1->3,2
# O's turn with move 6,1->5,2
# X's turn with move 3,0->4,1
# O's turn with move 5,2->3,0
# X's turn with move 3,2->4,3
# O's turn with move 3,0->2,1
# X's turn with move 0,1->1,2
# O's turn with move 2,1->0,3
# X's turn with move 4,3->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,3->3,2
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 5,4->4,5
# X's turn with move 1,4->2,3
# O's turn with move 5,6->4,7
# X's turn with move 2,1->3,2
# O's turn with move 6,5->5,6
# X's turn with move 1,2->2,1
# O's turn with move 7,4->6,5
# X's turn with move 3,2->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 4,5->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,6->3,4
# X's turn with move 2,1->3,2
# O's turn with move 3,4->2,3
# X's turn with move 1,6->2,5
# O's turn with move 6,7->5,6
# X's turn with move 4,3->5,4
# O's turn with move 6,3->4,5
# X's turn with move 0,3->1,2
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 6,1->5,2
# X's turn with move 1,2->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,0->2,1
# O's turn with move 7,6->6,7
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,1
# X's turn with move 5,0->7,2
# O's turn with move 7,0->6,1
# X's turn with move 0,1->1,2
# O's turn with move 2,3->0,1
# X's turn with move 0,5->1,4
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,1->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,5->4,3
# X's turn with move 4,7->6,5
# O's turn with move 4,3->3,2
# X's turn with move 0,7->1,6
# O's turn with move 3,2->2,1
# X's turn with move 2,7->3,6
# O's turn with move 2,1->1,0
# X's turn with move 3,6->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# X's turn with move 2,5->3,6
# O's turn with move 5,2->4,1
# X's turn with move 2,3->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 2,1->3,0
# O's turn with move 6,3->5,2
# X's turn with move 0,1->1,2
# O's turn with move 4,5->3,4
# X's turn with move 3,6->4,5
# O's turn with move 5,4->3,6
# X's turn with move 2,7->4,5
# O's turn with move 7,6->6,7
# X's turn with move 3,0->4,1
# O's turn with move 5,0->3,2
# X's turn with move 4,5->5,6
# O's turn with move 6,5->4,7
# X's turn with move 1,2->2,1
# O's turn with move 3,2->2,3
# X's turn with move 1,4->3,2
# O's turn with move 4,7->3,6
# X's turn with move 1,6->2,5
# O's turn with move 3,6->1,4
# X's turn with move 0,5->2,3
# O's turn with move 3,4->1,2
# X's turn with move 0,3->1,4
# O's turn with move 7,4->6,3
# X's turn with move 0,7->1,6
# O's turn with move 1,2->0,3
# X's turn with move 1,4->2,5
# O's turn with move 5,2->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,1->3,0
# O's turn with move 6,1->5,2
# X's turn with move 1,6->2,7
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 6,7->5,6
# X's turn with move 2,5->3,4
# O's turn with move 4,5->2,3
# X's turn with move 5,2->6,3
# O's turn with move 7,2->5,4
# X's turn with move 1,0->2,1
# O's turn with move 5,6->4,7
# X's turn with move 2,1->3,0
# O's turn with move 5,4->4,3
# X's turn with move 2,7->3,6
# O's turn with move 4,7->2,5
# X's turn with move 3,0->4,1
# O's turn with move 2,3->1,2
# X's turn with move 4,1->5,2
# O's turn with move 4,3->3,4
# X's turn with move 5,2->6,3
# O's turn with move 3,4->2,3
# X's turn with move 6,3->7,2
# O's turn with move 1,2->0,1
# X's turn with move 2,5->3,6
# O's turn with move 5,6->4,5
# X's turn with move 1,6->2,5
# O's turn with move 4,5->3,4
# X's turn with move 2,3->4,5
# O's turn with move 5,2->4,1
# X's turn with move 2,1->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 6,3->5,2
# X's turn with move 4,5->6,3
# O's turn with move 7,2->5,4
# X's turn with move 1,4->2,3
# O's turn with move 5,0->4,1
# X's turn with move 0,3->1,2
# O's turn with move 5,4->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,7->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,5->4,3
# X's turn with move 2,7->3,6
# O's turn with move 6,1->5,0
# X's turn with move 2,3->3,2
# O's turn with move 4,1->2,3
# X's turn with move 1,2->3,4
# O's turn with move 7,4->6,5
# X's turn with move 0,1->1,2
# O's turn with move 5,2->4,1
# X's turn with move 3,4->5,2
# O's turn with move 6,5->5,6
# X's turn with move 2,5->3,4
# O's turn with move 4,1->3,2
# X's turn with move 5,2->6,3
# O's turn with move 3,2->2,3
# X's turn with move 6,3->7,4
# O's turn with move 2,3->0,1
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 0,5->1,6
# O's turn with move 7,0->6,1
# X's turn with move 1,0->2,1
# O's turn with move 3,4->2,3
# X's turn with move 3,6->4,5
# O's turn with move 2,3->1,2
# X's turn with move 2,1->3,0
# O's turn with move 6,1->5,2
# X's turn with move 1,6->2,7
# O's turn with move 5,2->4,1
# X's turn with move 3,0->5,2
# O's turn with move 5,0->4,1
# X's turn with move 5,2->6,1
# O's turn with move 4,1->3,2
# X's turn with move 2,7->3,6
# O's turn with move 7,6->6,7
# X's turn with move 0,7->1,6
# O's turn with move 3,2->2,3
# X's turn with move 6,1->7,0
# O's turn with move 6,7->5,6
# X's turn with move 4,5->6,7
# O's turn with move 2,3->1,4
# X's turn with move 3,6->4,7
# O's turn with move 1,2->0,3
# X's turn with move 1,6->2,5
# O's turn with move 1,4->0,5
# X's turn with move 6,7->7,6
# X's turn with move 2,1->3,2
# O's turn with move 5,4->4,5
# X's turn with move 2,5->3,6
# O's turn with move 6,3->5,4
# X's turn with move 3,2->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,0->2,1
# O's turn with move 7,2->6,3
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,4->3,2
# O's turn with move 6,3->5,2
# X's turn with move 3,6->4,5
# O's turn with move 5,6->3,4
# X's turn with move 0,1->1,0
# O's turn with move 5,2->4,3
# X's turn with move 0,3->1,4
# O's turn with move 5,4->4,5
# X's turn with move 3,2->5,4
# O's turn with move 6,5->4,3
# X's turn with move 1,6->2,5
# O's turn with move 3,4->1,6
# X's turn with move 0,7->2,5
# O's turn with move 7,4->6,3
# X's turn with move 1,4->2,3
# O's turn with move 7,6->6,5
# X's turn with move 2,1->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,5->5,6
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,2->3,4
# O's turn with move 6,3->5,2
# X's turn with move 3,2->4,3
# O's turn with move 5,6->4,7
# X's turn with move 4,3->5,4
# O's turn with move 5,2->4,1
# X's turn with move 3,4->4,3
# O's turn with move 6,1->5,2
# X's turn with move 4,3->6,1
# O's turn with move 7,0->5,2
# X's turn with move 0,5->1,6
# O's turn with move 6,7->5,6
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,2->4,3
# X's turn with move 3,4->5,2
# O's turn with move 4,1->3,2
# X's turn with move 5,4->6,3
# O's turn with move 5,0->4,1
# X's turn with move 6,3->7,2
# O's turn with move 3,0->2,1
# X's turn with move 2,7->3,6
# O's turn with move 4,1->3,0
# X's turn with move 5,2->6,1
# O's turn with move 5,6->4,7
# X's turn with move 3,6->4,5
# O's turn with move 3,2->2,3
# X's turn with move 6,1->7,0
# O's turn with move 2,3->1,4
# X's turn with move 4,5->5,4
# O's turn with move 4,7->3,6
# X's turn with move 5,4->6,5
# O's turn with move 3,6->2,7
# X's turn with move 6,5->7,6
# O's turn with move 2,7->1,6
# X's turn with move 2,1->3,2
# O's turn with move 5,4->4,3
# X's turn with move 3,2->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 2,3->3,4
# O's turn with move 7,4->6,3
# X's turn with move 1,4->2,3
# O's turn with move 6,3->5,4
# X's turn with move 1,2->2,1
# O's turn with move 5,4->4,3
# X's turn with move 2,1->3,0
# O's turn with move 7,2->6,3
# X's turn with move 0,1->1,2
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,5->4,7
# X's turn with move 1,2->2,1
# O's turn with move 4,7->3,6
# X's turn with move 2,5->4,7
# O's turn with move 4,3->3,2
# X's turn with move 2,1->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,3->4,5
# O's turn with move 6,7->5,6
# X's turn with move 4,7->6,5
# O's turn with move 7,6->5,4
# X's turn with move 4,5->5,6
# O's turn with move 5,4->4,3
# X's turn with move 3,0->4,1
# O's turn with move 5,0->3,2
# X's turn with move 0,5->1,4
# O's turn with move 2,7->0,5
# X's turn with move 5,6->6,7
# O's turn with move 6,3->5,2
# X's turn with move 0,3->1,2
# O's turn with move 5,2->4,1
# X's turn with move 1,2->2,1
# O's turn with move 4,1->3,0
# X's turn with move 0,7->1,6
# O's turn with move 3,0->1,2
# X's turn with move 1,6->2,7
# O's turn with move 3,2->2,3
# X's turn with move 1,4->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,1->5,0
# X's turn with move 2,7->3,6
# O's turn with move 1,2->0,1
# X's turn with move 3,6->4,5
# O's turn with move 7,0->6,1
# X's turn with move 4,5->5,4
# O's turn with move 6,1->5,2
# X's turn with move 5,4->6,3
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 5,2->4,1
# X's turn with move 6,3->7,4
# O's turn with move 4,1->3,0
# X's turn with move 5,0->6,1
# O's turn with move 3,0->2,1
# X's turn with move 6,1->7,0
# O's turn with move 2,1->1,2
# X's turn with move 6,7->7,6
# O's turn with move 1,2->0,3
# X's turn with move 2,3->3,2
# O's turn with move 5,6->4,7
# X's turn with move 3,2->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,2->2,3
# O's turn with move 3,0->1,2
# X's turn with move 0,3->2,1
# O's turn with move 5,4->4,5
# X's turn with move 2,3->3,4
# O's turn with move 4,5->2,3
# X's turn with move 1,4->3,2
# O's turn with move 6,7->5,6
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,6->3,4
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 6,5->5,4
# X's turn with move 0,5->1,6
# O's turn with move 5,6->4,5
# X's turn with move 3,4->5,6
# O's turn with move 6,3->5,2
# X's turn with move 5,6->6,5
# O's turn with move 7,4->5,6
# X's turn with move 2,1->3,2
# O's turn with move 5,2->4,3
# X's turn with move 0,1->1,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 7,6->6,5
# X's turn with move 2,7->3,6
# O's turn with move 5,6->4,5
# X's turn with move 1,6->2,5
# O's turn with move 4,5->2,7
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,5->3,6
# O's turn with move 3,2->2,1
# X's turn with move 1,2->3,0
# O's turn with move 2,7->1,6
# X's turn with move 0,7->2,5
# O's turn with move 6,1->5,2
# X's turn with move 5,0->6,1
# O's turn with move 7,2->5,0
# X's turn with move 3,6->4,7
# O's turn with move 5,0->4,1
# X's turn with move 2,5->3,4
# O's turn with move 4,1->3,2
# X's turn with move 4,7->5,6
# O's turn with move 6,5->4,7
# X's turn with move 3,4->4,5
# O's turn with move 3,2->2,3
# X's turn with move 4,5->5,4
# O's turn with move 7,0->6,1
# X's turn with move 3,0->4,1
# O's turn with move 5,2->3,0
# X's turn with move 5,4->6,5
# O's turn with move 6,1->5,2
# X's turn with move 6,5->7,4
# O's turn with move 2,3->1,4
# X's turn with move 2,1->3,2
# O's turn with move 5,0->4,1
# X's turn with move 3,2->5,0
# O's turn with move 5,6->4,7
# X's turn with move 2,5->3,6
# O's turn with move 4,7->2,5
# X's turn with move 1,4->3,6
# O's turn with move 5,4->4,3
# X's turn with move 2,3->3,2
# O's turn with move 4,3->2,1
# X's turn with move 1,0->3,2
# O's turn with move 6,3->5,4
# X's turn with move 1,2->2,3
# O's turn with move 7,4->6,3
# X's turn with move 0,3->1,4
# O's turn with move 6,7->5,6
# X's turn with move 3,2->4,3
# O's turn with move 5,4->3,2
# X's turn with move 2,3->4,1
# O's turn with move 5,2->3,0
# X's turn with move 1,6->2,5
# O's turn with move 5,6->4,5
# X's turn with move 3,6->5,4
# O's turn with move 6,3->4,5
# X's turn with move 2,7->3,6
# O's turn with move 4,5->2,7
# X's turn with move 0,7->1,6
# O's turn with move 7,2->6,3
# X's turn with move 5,0->7,2
# O's turn with move 6,5->5,6
# X's turn with move 2,5->3,4
# O's turn with move 7,0->6,1
# X's turn with move 3,4->4,5
# O's turn with move 5,6->3,4
# X's turn with move 0,1->1,0
# O's turn with move 3,0->2,1
# X's turn with move 1,0->3,2
# O's turn with move 3,4->2,3
# X's turn with move 1,4->2,5
# O's turn with move 6,1->5,2
# X's turn with move 3,2->4,3
# O's turn with move 5,2->3,4
# X's turn with move 2,5->4,3
# O's turn with move 7,6->6,7
# X's turn with move 4,3->5,4
# O's turn with move 6,3->4,5
# X's turn with move 0,5->1,4
# O's turn with move 2,7->0,5
# X's turn with move 1,4->3,2
# O's turn with move 4,5->3,4
# X's turn with move 3,2->4,3
# O's turn with move 3,4->2,5
# X's turn with move 4,3->5,4
# O's turn with move 6,7->5,6
# X's turn with move 5,4->6,3
# O's turn with move 5,6->4,7
# X's turn with move 6,3->7,4
# O's turn with move 4,7->3,6
# 24.446057840999856
